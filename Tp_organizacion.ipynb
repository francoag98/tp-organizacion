# %% [markdown]
# <a href="https://colab.research.google.com/github/francoag98/tp-organizacion/blob/main/Tp_organizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/francoag98/tp-organizacion.git
# Out:
# Cloning into 'tp-organizacion'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 15 (delta 0), reused 12 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 56.96 KiB | 3.16 MiB/s, done.

# %%
# !git pull origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git config --global user.email "francoaglieri@hotmail.com"
# !git config --global user.name "Franco Aglieri"
